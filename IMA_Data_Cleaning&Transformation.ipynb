# %%
# Authenticate and access Google Cloud services
from google.colab import auth
auth.authenticate_user()

# %%
# Import the necessary libraries
from google.cloud import storage
from google.cloud import bigquery

# %%
def create_dataset(project_id, dataset_id, location="US"):
    client = bigquery.Client(project=project_id)
    dataset_ref = bigquery.DatasetReference(project_id, dataset_id)
    dataset = bigquery.Dataset(dataset_ref)
    dataset.location = location

    created_dataset = client.create_dataset(dataset, timeout=30)  # Waits 30 seconds
    print("Dataset {} created.".format(created_dataset.dataset_id))

# Usage
create_dataset('pristine-flames-422615-m1', 'ima_dataset') # Replace 'your-project-id' with your Google Cloud project ID and 'your-new-datatset-name' with your desired dataset name
# Out:
# ---------------------------------------------------------------------------
# Conflict                                  Traceback (most recent call last)
# <ipython-input-3-0ed3d3d7a38b> in <cell line: 11>()
#       9
#      10 # Usage
# ---> 11 create_dataset('pristine-flames-422615-m1', 'ima_dataset') # Replace 'your-project-id' with your Google Cloud project ID and 'your-new-datatset-name' with your desired dataset name
#
# <ipython-input-3-0ed3d3d7a38b> in create_dataset(project_id, dataset_id, location)
#       5     dataset.location = location
#       6
# ----> 7     created_dataset = client.create_dataset(dataset, timeout=30)  # Waits 30 seconds
#       8     print("Dataset {} created.".format(created_dataset.dataset_id))
#       9
#
# /usr/local/lib/python3.10/dist-packages/google/cloud/bigquery/client.py in create_dataset(self, dataset, exists_ok, retry, timeout)
#     679             span_attributes = {"path": path}
#     680
# ...

# %%
# Load the restaurant data into BigQuery
# Replace 'your-project-id' with your Google Cloud project ID
# Replace 'your-dataset-name' with your dataset name
# (optional) you could change the table name with a new name but not a problem not to change
project_id = "pristine-flames-422615-m1"
dataset_name = "ima_dataset"
table_name = "restaurant_data"
bucket_name = "yelp-data-bdao" # don't make changes here
blob_name = "restaurant_data.csv" # don't make changes here

bigquery_client = bigquery.Client(project=project_id)

dataset_ref = bigquery_client.dataset(dataset_name)
table_ref = dataset_ref.table(table_name)

job_config = bigquery.LoadJobConfig()
job_config.autodetect = True
job_config.source_format = bigquery.SourceFormat.CSV

load_job = bigquery_client.load_table_from_uri(
    f"gs://{bucket_name}/{blob_name}",
    table_ref,
    job_config=job_config
)

load_job.result()

print(f"Data loaded into BigQuery: {project_id}.{dataset_name}.{table_name}")
# Out:
# Data loaded into BigQuery: pristine-flames-422615-m1.ima_dataset.restaurant_data

# %%
# Load the restaurant tips data into BigQuery
# Replace 'your-project-id' with your Google Cloud project ID
# Replace 'your-dataset-name' with your dataset name
# (optional) you could change the table name with a new name but not a problem not to change
project_id = "pristine-flames-422615-m1"
dataset_name = "ima_dataset"
table_name = "restaurant_tips"
bucket_name = "yelp-data-bdao" # don't make changes here
blob_name = "restaurant_tips.csv" # don't make changes here

bigquery_client = bigquery.Client(project=project_id)

dataset_ref = bigquery_client.dataset(dataset_name)
table_ref = dataset_ref.table(table_name)

job_config = bigquery.LoadJobConfig()
job_config.autodetect = True
job_config.source_format = bigquery.SourceFormat.CSV

load_job = bigquery_client.load_table_from_uri(
    f"gs://{bucket_name}/{blob_name}",
    table_ref,
    job_config=job_config
)

load_job.result()

print(f"Data loaded into BigQuery: {project_id}.{dataset_name}.{table_name}")
# Out:
# Data loaded into BigQuery: pristine-flames-422615-m1.ima_dataset.restaurant_tips

# %%
# Load the data into BigQuery
# Replace 'your-project-id' with your Google Cloud project ID
# Replace 'your-dataset-name' with your dataset name
# (optional) you could change the table name with a new name but not a problem not to change
project_id = "pristine-flames-422615-m1"
dataset_name = "ima_dataset"
table_name = "restaurant_checkin"
bucket_name = "yelp-data-bdao" # don't make changes here
blob_name = "restaurant_checkin.csv" # don't make changes here

bigquery_client = bigquery.Client(project=project_id)

dataset_ref = bigquery_client.dataset(dataset_name)
table_ref = dataset_ref.table(table_name)

job_config = bigquery.LoadJobConfig()
job_config.autodetect = True
job_config.source_format = bigquery.SourceFormat.CSV

load_job = bigquery_client.load_table_from_uri(
    f"gs://{bucket_name}/{blob_name}",
    table_ref,
    job_config=job_config
)

load_job.result()

print(f"Data loaded into BigQuery: {project_id}.{dataset_name}.{table_name}")
# Out:
# Data loaded into BigQuery: pristine-flames-422615-m1.ima_dataset.restaurant_checkin

# %%
# Import the necessary libraries
from google.cloud import storage
from google.cloud import bigquery

# First make connection to BigQuery
# Replace 'your-project-id' with your Google Cloud project ID
# Replace 'your-dataset-name' with your dataset name
project_id = "pristine-flames-422615-m1"
dataset_name = "ima_dataset"
table_names = ["restaurant_data", "restaurant_tips", "restaurant_checkin"] # if you make changes previously, then here you need to make according change

bigquery_client = bigquery.Client(project=project_id)

# %%
# Query all data from the table
query = f"""
    SELECT *
    FROM `{project_id}.{dataset_name}.restaurant_data`
    ORDER BY business_id
"""

query_job_data = bigquery_client.query(query)
results = query_job_data.result()

restaurant_data_df = query_job_data.to_dataframe()
restaurant_data_df
# Out:
#                    business_id                          name  \
# 0       ---kPU91CF4Lq2-WlRu9Lw             Frankie's Raw Bar
# 1       ---kPU91CF4Lq2-WlRu9Lw             Frankie's Raw Bar
# 2       ---kPU91CF4Lq2-WlRu9Lw             Frankie's Raw Bar
# 3       ---kPU91CF4Lq2-WlRu9Lw             Frankie's Raw Bar
# 4       --0iUa4sNDFiZFrAdIWhZQ  Pupuseria Y Restaurant Melba
# ...                        ...                           ...
# 209139  zzu6_r3DxBJuXcjnOYVdTw                  Cafe Diblasi
# 209140  zzyx5x0Z7xXWWvWnZFuxlQ           Walnut Street Pizza
# 209141  zzyx5x0Z7xXWWvWnZFuxlQ           Walnut Street Pizza
# 209142  zzyx5x0Z7xXWWvWnZFuxlQ           Walnut Street Pizza
# 209143  zzyx5x0Z7xXWWvWnZFuxlQ           Walnut Street Pizza
#
#                         address             city state postal_code   latitude  \
# 0              4903 State Rd 54  New Port Richey    FL       34652  28.217288
# ...

# %%
restaurant_data_df.duplicated(subset=['business_id']).sum()
# Out:
# 156858

# %%
restaurant_data_df_clean = restaurant_data_df.drop_duplicates(subset=['business_id'], keep='first')

# %%
restaurant_data_df_clean['business_id'].isnull().sum()
# Out:
# 0

# %%
cols_to_select = restaurant_data_df_clean[['business_id', 'stars', 'review_count', 'is_open']]
cols_to_select
# Out:
#                    business_id  stars  review_count  is_open
# 0       ---kPU91CF4Lq2-WlRu9Lw    4.5            24        1
# 4       --0iUa4sNDFiZFrAdIWhZQ    3.0            14        1
# 8       --7PUidqRWpRSpXebiyxTg    2.0            12        0
# 12      --8IbOsAAxjKRoYsBFL-PA    3.0            27        0
# 16      --ZVrH2X2QXBFdCilbirsw    4.5            32        0
# ...                        ...    ...           ...      ...
# 209124  zzjFdJwXuxBOGe9JeY_EMw    4.0            47        1
# 209128  zznJox6-nmXlGYNWgTDwQQ    1.5            30        1
# 209132  zznZqH9CiAznbkV6fXyHWA    5.0            12        1
# 209136  zzu6_r3DxBJuXcjnOYVdTw    3.5             8        0
# 209140  zzyx5x0Z7xXWWvWnZFuxlQ    2.5             6        0
#
# [52286 rows x 4 columns]

# %%
cols_to_select.dtypes
# Out:
# business_id      object
# stars           float64
# review_count      Int64
# is_open           Int64
# dtype: object

# %%
cols_to_select['business_id'] = cols_to_select['business_id'].astype(str)
# Out:
# <ipython-input-10-5c8bc2a41072>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cols_to_select['business_id'] = cols_to_select['business_id'].astype(str)

# %%
print(cols_to_select.dtypes)
# Out:
# business_id      object
# stars           float64
# review_count      Int64
# is_open           Int64
# dtype: object

# %%
last_33_columns = restaurant_data_df_clean.iloc[:, -33:]
missing_counts = last_33_columns.isnull().sum()
total_rows = len(restaurant_data_df_clean)
missing_percentages = (missing_counts / total_rows) * 100
print(missing_percentages)
# Out:
# RestaurantsDelivery           13.816318
# OutdoorSeating                19.896339
# BusinessAcceptsCreditCards    12.888727
# BusinessParking               14.147190
# BikeParking                   32.178786
# RestaurantsPriceRange2        14.896913
# RestaurantsTakeOut             8.901044
# ByAppointmentOnly             93.596756
# WiFi                          27.871706
# Alcohol                       23.600964
# Caters                        33.967028
# RestaurantsAttire             25.496309
# RestaurantsReservations       18.033508
# Ambience                      21.512451
# GoodForKids                   21.671193
# CoatCheck                     91.818077
# DogsAllowed                   78.068699
# RestaurantsTableService       62.280534
# RestaurantsGoodForGroups      20.783766
# WheelchairAccessible          74.082929
# HasTV                         19.865738
# HappyHour                     75.123360
# DriveThru                     88.777111
# ...

# %%
columns_to_keep = missing_percentages[missing_percentages <= 40].index
filtered_df = last_33_columns.loc[:, columns_to_keep]
#filtered_df.to_csv('filtered_data.csv', index=False)
filtered_df
# Out:
#         RestaurantsDelivery  OutdoorSeating  BusinessAcceptsCreditCards  \
# 0                     False            True                        True
# 4                     False            <NA>                       False
# 8                      True           False                        <NA>
# 12                     True           False                        True
# 16                    False           False                        True
# ...                     ...             ...                         ...
# 209124                 True            True                        True
# 209128                 True            True                        True
# 209132                False            True                        True
# 209136                False           False                        True
# 209140                False           False                        True
#
#                                           BusinessParking  BikeParking  \
# ...

# %%
filtered_df[['RestaurantsDelivery', 'OutdoorSeating', 'BusinessAcceptsCreditCards', 'BikeParking', 'RestaurantsTakeOut', 'Caters', 'RestaurantsReservations', 'GoodForKids', 'RestaurantsGoodForGroups', 'HasTV', 'Parking']] = filtered_df[['RestaurantsDelivery', 'OutdoorSeating', 'BusinessAcceptsCreditCards', 'BikeParking', 'RestaurantsTakeOut', 'Caters', 'RestaurantsReservations', 'GoodForKids', 'RestaurantsGoodForGroups', 'HasTV', 'Parking']].fillna(value=False)
filtered_df = filtered_df.drop(['BusinessParking','Ambience'], axis = 1)
filtered_df.head()
# Out:
#     RestaurantsDelivery  OutdoorSeating  BusinessAcceptsCreditCards  \
# 0                 False            True                        True
# 4                 False           False                       False
# 8                  True           False                       False
# 12                 True           False                        True
# 16                False           False                        True
#
#     BikeParking  RestaurantsPriceRange2  RestaurantsTakeOut    WiFi Alcohol  \
# 0          True                    <NA>                True    'no'  'none'
# 4         False                       1                True    None  'none'
# 8         False                       2                True    None    None
# 12         True                       2                True  'free'  'none'
# 16         True                       1                True  'free'  'none'
#
#     Caters RestaurantsAttire  RestaurantsReservations  GoodForKids  \
# ...

# %%
import pandas as pd
attributes = pd.concat([cols_to_select, filtered_df], axis=1)
attributes
# Out:
#                    business_id  stars  review_count  is_open  \
# 0       ---kPU91CF4Lq2-WlRu9Lw    4.5            24        1
# 4       --0iUa4sNDFiZFrAdIWhZQ    3.0            14        1
# 8       --7PUidqRWpRSpXebiyxTg    2.0            12        0
# 12      --8IbOsAAxjKRoYsBFL-PA    3.0            27        0
# 16      --ZVrH2X2QXBFdCilbirsw    4.5            32        0
# ...                        ...    ...           ...      ...
# 209124  zzjFdJwXuxBOGe9JeY_EMw    4.0            47        1
# 209128  zznJox6-nmXlGYNWgTDwQQ    1.5            30        1
# 209132  zznZqH9CiAznbkV6fXyHWA    5.0            12        1
# 209136  zzu6_r3DxBJuXcjnOYVdTw    3.5             8        0
# 209140  zzyx5x0Z7xXWWvWnZFuxlQ    2.5             6        0
#
#         RestaurantsDelivery  OutdoorSeating  BusinessAcceptsCreditCards  \
# 0                     False            True                        True
# 4                     False           False                       False
# ...

# %%
attributes.isnull().sum()
# Out:
# business_id                       0
# stars                             0
# review_count                      0
# is_open                           0
# RestaurantsDelivery               0
# OutdoorSeating                    0
# BusinessAcceptsCreditCards        0
# BikeParking                       0
# RestaurantsPriceRange2         7789
# RestaurantsTakeOut                0
# WiFi                          14573
# Alcohol                       12340
# Caters                            0
# RestaurantsAttire             13331
# RestaurantsReservations           0
# GoodForKids                       0
# RestaurantsGoodForGroups          0
# HasTV                             0
# NoiseLevel                    17478
# Parking                           0
# dtype: int64

# %%
attributes[['RestaurantsDelivery', 'OutdoorSeating', 'BusinessAcceptsCreditCards', 'BikeParking', 'RestaurantsTakeOut', 'Caters', 'RestaurantsReservations', 'GoodForKids', 'RestaurantsGoodForGroups', 'HasTV', 'Parking']] = attributes[['RestaurantsDelivery', 'OutdoorSeating', 'BusinessAcceptsCreditCards', 'BikeParking', 'RestaurantsTakeOut', 'Caters', 'RestaurantsReservations', 'GoodForKids', 'RestaurantsGoodForGroups', 'HasTV', 'Parking']].replace({
    'False': 0,
    'True': 1
})
attributes[['RestaurantsDelivery', 'OutdoorSeating', 'BusinessAcceptsCreditCards', 'BikeParking', 'RestaurantsTakeOut', 'Caters', 'RestaurantsReservations', 'GoodForKids', 'RestaurantsGoodForGroups', 'HasTV', 'Parking']] = attributes[['RestaurantsDelivery', 'OutdoorSeating', 'BusinessAcceptsCreditCards', 'BikeParking', 'RestaurantsTakeOut', 'Caters', 'RestaurantsReservations', 'GoodForKids', 'RestaurantsGoodForGroups', 'HasTV', 'Parking']].astype(int)
attributes.head()
# Out:
#                business_id  stars  review_count  is_open  RestaurantsDelivery  \
# 0   ---kPU91CF4Lq2-WlRu9Lw    4.5            24        1                    0
# 4   --0iUa4sNDFiZFrAdIWhZQ    3.0            14        1                    0
# 8   --7PUidqRWpRSpXebiyxTg    2.0            12        0                    1
# 12  --8IbOsAAxjKRoYsBFL-PA    3.0            27        0                    1
# 16  --ZVrH2X2QXBFdCilbirsw    4.5            32        0                    0
#
#     OutdoorSeating  BusinessAcceptsCreditCards  BikeParking  \
# 0                1                           1            1
# 4                0                           0            0
# 8                0                           0            0
# 12               0                           1            1
# 16               0                           1            1
#
#     RestaurantsPriceRange2  RestaurantsTakeOut    WiFi Alcohol  Caters  \
# ...

# %%
attributes['RestaurantsPriceRange2'].describe()
nan_rows = attributes[attributes['RestaurantsPriceRange2'].isna()]
nan_rows
# Out:
#                    business_id  stars  review_count  is_open  \
# 0       ---kPU91CF4Lq2-WlRu9Lw    4.5            24        1
# 24      --hF_3v1JmU9nlu4zfXJ8Q    4.5            15        1
# 44      -0EdehHjIQc0DtYU8QcAig    3.0            35        1
# 48      -0FX23yAacC4bbLaGPvyxw    3.5           155        1
# 104     -0ltw8--HLuulPyOSspqAQ    3.0            11        1
# ...                        ...    ...           ...      ...
# 208816  zucC7rHpXPYBu7aEqj0NUw    4.0           117        1
# 208904  zvvl3c1FO3O3BZdhusficA    4.0            29        1
# 209084  zz07slKrNwzX_1uiF8QL6g    1.5            10        1
# 209108  zzXRdzrVhfNWPHD2MeyWeA    2.0            14        1
# 209132  zznZqH9CiAznbkV6fXyHWA    5.0            12        1
#
#         RestaurantsDelivery  OutdoorSeating  BusinessAcceptsCreditCards  \
# 0                         0               1                           1
# 24                        1               1                           1
# ...

# %%
attributes.describe()
mode_RestaurantsPriceRange2 = attributes['RestaurantsPriceRange2'].mode()
attributes['RestaurantsPriceRange2'] = attributes['RestaurantsPriceRange2'].fillna(2)
attributes.head()
# Out:
#                business_id  stars  review_count  is_open  RestaurantsDelivery  \
# 0   ---kPU91CF4Lq2-WlRu9Lw    4.5            24        1                    0
# 4   --0iUa4sNDFiZFrAdIWhZQ    3.0            14        1                    0
# 8   --7PUidqRWpRSpXebiyxTg    2.0            12        0                    1
# 12  --8IbOsAAxjKRoYsBFL-PA    3.0            27        0                    1
# 16  --ZVrH2X2QXBFdCilbirsw    4.5            32        0                    0
#
#     OutdoorSeating  BusinessAcceptsCreditCards  BikeParking  \
# 0                1                           1            1
# 4                0                           0            0
# 8                0                           0            0
# 12               0                           1            1
# 16               0                           1            1
#
#     RestaurantsPriceRange2  RestaurantsTakeOut    WiFi Alcohol  Caters  \
# ...

# %%
attributes['WiFi'] = attributes['WiFi'].astype(str).str.strip("'").str.lower()
attributes['WiFi'].fillna(0, inplace=True)
attributes['WiFi'] = attributes['WiFi'].replace({
    'no': 0,
    'free': 1,
    'paid': 0,
    'none': 0
})
attributes['WiFi'] = attributes['WiFi'].astype(int)
attributes.head()
# Out:
#                business_id  stars  review_count  is_open  RestaurantsDelivery  \
# 0   ---kPU91CF4Lq2-WlRu9Lw    4.5            24        1                    0
# 4   --0iUa4sNDFiZFrAdIWhZQ    3.0            14        1                    0
# 8   --7PUidqRWpRSpXebiyxTg    2.0            12        0                    1
# 12  --8IbOsAAxjKRoYsBFL-PA    3.0            27        0                    1
# 16  --ZVrH2X2QXBFdCilbirsw    4.5            32        0                    0
#
#     OutdoorSeating  BusinessAcceptsCreditCards  BikeParking  \
# 0                1                           1            1
# 4                0                           0            0
# 8                0                           0            0
# 12               0                           1            1
# 16               0                           1            1
#
#     RestaurantsPriceRange2  RestaurantsTakeOut  WiFi Alcohol  Caters  \
# ...

# %%
attributes['WiFi'].unique()
# Out:
# array([0, 1])

# %%
attributes['Alcohol'] = attributes['Alcohol'].astype(str).str.strip("'").str.lower()
attributes['Alcohol'].fillna(0, inplace=True)
attributes['Alcohol'] = attributes['Alcohol'].replace({
    'none': 0,
    'beer_and_wine': 1,
    'full_bar': 2
})
attributes['Alcohol'] = attributes['Alcohol'].astype(int)
attributes.head()
# Out:
#                business_id  stars  review_count  is_open  RestaurantsDelivery  \
# 0   ---kPU91CF4Lq2-WlRu9Lw    4.5            24        1                    0
# 4   --0iUa4sNDFiZFrAdIWhZQ    3.0            14        1                    0
# 8   --7PUidqRWpRSpXebiyxTg    2.0            12        0                    1
# 12  --8IbOsAAxjKRoYsBFL-PA    3.0            27        0                    1
# 16  --ZVrH2X2QXBFdCilbirsw    4.5            32        0                    0
#
#     OutdoorSeating  BusinessAcceptsCreditCards  BikeParking  \
# 0                1                           1            1
# 4                0                           0            0
# 8                0                           0            0
# 12               0                           1            1
# 16               0                           1            1
#
#     RestaurantsPriceRange2  RestaurantsTakeOut  WiFi  Alcohol  Caters  \
# ...

# %%
attributes['Alcohol'].unique()
# Out:
# array([0, 1, 2])

# %%
attributes['RestaurantsAttire'] = attributes['RestaurantsAttire'].astype(str).str.strip("'").str.lower()
attributes['RestaurantsAttire'].fillna(0, inplace=True)
attributes['RestaurantsAttire'] = attributes['RestaurantsAttire'].replace({
    'casual': 0,
    'dressy': 1,
    'formal': 2,
    'none': 0
})
attributes['RestaurantsAttire'] = attributes['RestaurantsAttire'].astype(int)
attributes.head()
# Out:
#                business_id  stars  review_count  is_open  RestaurantsDelivery  \
# 0   ---kPU91CF4Lq2-WlRu9Lw    4.5            24        1                    0
# 4   --0iUa4sNDFiZFrAdIWhZQ    3.0            14        1                    0
# 8   --7PUidqRWpRSpXebiyxTg    2.0            12        0                    1
# 12  --8IbOsAAxjKRoYsBFL-PA    3.0            27        0                    1
# 16  --ZVrH2X2QXBFdCilbirsw    4.5            32        0                    0
#
#     OutdoorSeating  BusinessAcceptsCreditCards  BikeParking  \
# 0                1                           1            1
# 4                0                           0            0
# 8                0                           0            0
# 12               0                           1            1
# 16               0                           1            1
#
#     RestaurantsPriceRange2  RestaurantsTakeOut  WiFi  Alcohol  Caters  \
# ...

# %%
attributes['RestaurantsAttire'].unique()
# Out:
# array([0, 1, 2])

# %%
attributes['NoiseLevel'] = attributes['NoiseLevel'].astype(str).str.strip("'").str.lower()
attributes['NoiseLevel'].fillna('average', inplace=True)
attributes['NoiseLevel'] = attributes['NoiseLevel'].replace({
    'quiet': 0,
    'average': 1,
    'loud': 2,
    'very_loud': 3,
    'none': 1
})
attributes.head()
# Out:
#                business_id  stars  review_count  is_open  RestaurantsDelivery  \
# 0   ---kPU91CF4Lq2-WlRu9Lw    4.5            24        1                    0
# 4   --0iUa4sNDFiZFrAdIWhZQ    3.0            14        1                    0
# 8   --7PUidqRWpRSpXebiyxTg    2.0            12        0                    1
# 12  --8IbOsAAxjKRoYsBFL-PA    3.0            27        0                    1
# 16  --ZVrH2X2QXBFdCilbirsw    4.5            32        0                    0
#
#     OutdoorSeating  BusinessAcceptsCreditCards  BikeParking  \
# 0                1                           1            1
# 4                0                           0            0
# 8                0                           0            0
# 12               0                           1            1
# 16               0                           1            1
#
#     RestaurantsPriceRange2  RestaurantsTakeOut  WiFi  Alcohol  Caters  \
# ...

# %%
attributes['NoiseLevel'].unique()
# Out:
# array([1, 0, 2, 3])

# %%
attributes.isnull().sum()
# Out:
# business_id                   0
# stars                         0
# review_count                  0
# is_open                       0
# RestaurantsDelivery           0
# OutdoorSeating                0
# BusinessAcceptsCreditCards    0
# BikeParking                   0
# RestaurantsPriceRange2        0
# RestaurantsTakeOut            0
# WiFi                          0
# Alcohol                       0
# Caters                        0
# RestaurantsAttire             0
# RestaurantsReservations       0
# GoodForKids                   0
# RestaurantsGoodForGroups      0
# HasTV                         0
# NoiseLevel                    0
# Parking                       0
# dtype: int64

# %%
attributes.dtypes
# Out:
# business_id                    object
# stars                         float64
# review_count                    Int64
# is_open                         Int64
# RestaurantsDelivery             int64
# OutdoorSeating                  int64
# BusinessAcceptsCreditCards      int64
# BikeParking                     int64
# RestaurantsPriceRange2          Int64
# RestaurantsTakeOut              int64
# WiFi                            int64
# Alcohol                         int64
# Caters                          int64
# RestaurantsAttire               int64
# RestaurantsReservations         int64
# GoodForKids                     int64
# RestaurantsGoodForGroups        int64
# HasTV                           int64
# NoiseLevel                      int64
# Parking                         int64
# dtype: object

# %%
attributes.to_csv('restaurants_attributes.csv', index=False)

# %% [markdown]
# ### 以上是雪珑的

# %%
query = f"""
    SELECT *
    FROM `{project_id}.{dataset_name}.restaurant_checkin`
    ORDER BY business_id
"""

query_job_checkin = bigquery_client.query(query)
results = query_job_checkin.result()

restaurant_checkin_df = query_job_checkin.to_dataframe()
restaurant_checkin_df.head()
# Out:
#               business_id                      date  total_number_of_checkin  \
# 0  ---kPU91CF4Lq2-WlRu9Lw 2020-03-13 21:10:56+00:00                       11
# 1  ---kPU91CF4Lq2-WlRu9Lw 2021-08-06 21:08:08+00:00                       11
# 2  ---kPU91CF4Lq2-WlRu9Lw 2020-10-24 21:36:13+00:00                       11
# 3  ---kPU91CF4Lq2-WlRu9Lw 2021-05-25 21:16:54+00:00                       11
# 4  ---kPU91CF4Lq2-WlRu9Lw 2021-01-20 17:34:57+00:00                       11
#
#    restaurant  year  month  day  hour
# 0        True  2020      3   13    21
# 1        True  2021      8    6    21
# 2        True  2020     10   24    21
# 3        True  2021      5   25    21
# 4        True  2021      1   20    17

# %%
restaurant_checkin_df.describe()
# Out:
#        total_number_of_checkin         year       month         day  \
# count               17031164.0   17031164.0  17031164.0  17031164.0
# mean               1480.546202  2015.401235     6.47935   15.770742
# std                3754.735595     2.751444    3.401619    8.807844
# min                        1.0       2009.0         1.0         1.0
# 25%                      216.0       2013.0         4.0         8.0
# 50%                      559.0       2015.0         6.0        16.0
# 75%                     1347.0       2017.0         9.0        23.0
# max                    40109.0       2022.0        12.0        31.0
#
#              hour
# count  17031164.0
# mean    13.429553
# std      8.421359
# min           0.0
# 25%           3.0
# 50%          17.0
# 75%          20.0
# max          23.0

# %%
restaurant_checkin_df.duplicated().sum()
# Out:
# 8517905

# %%
restaurant_checkin_df_clean = restaurant_checkin_df.drop_duplicates()

# %%
restaurant_checkin_df_clean.isnull().sum()
# Out:
# business_id                0
# date                       0
# total_number_of_checkin    0
# restaurant                 0
# year                       0
# month                      0
# day                        0
# hour                       0
# dtype: int64

# %%
restaurant_checkin_df_clean
# Out:
#                      business_id                      date  \
# 0         ---kPU91CF4Lq2-WlRu9Lw 2020-03-13 21:10:56+00:00
# 1         ---kPU91CF4Lq2-WlRu9Lw 2021-08-06 21:08:08+00:00
# 2         ---kPU91CF4Lq2-WlRu9Lw 2020-10-24 21:36:13+00:00
# 3         ---kPU91CF4Lq2-WlRu9Lw 2021-05-25 21:16:54+00:00
# 4         ---kPU91CF4Lq2-WlRu9Lw 2021-01-20 17:34:57+00:00
# ...                          ...                       ...
# 17031141  zzu6_r3DxBJuXcjnOYVdTw 2012-10-28 00:35:18+00:00
# 17031145  zzu6_r3DxBJuXcjnOYVdTw 2013-07-14 00:29:38+00:00
# 17031146  zzu6_r3DxBJuXcjnOYVdTw 2013-05-09 23:59:54+00:00
# 17031148  zzu6_r3DxBJuXcjnOYVdTw 2013-12-13 00:58:14+00:00
# 17031162  zzyx5x0Z7xXWWvWnZFuxlQ 2015-01-06 17:51:53+00:00
#
#           total_number_of_checkin  restaurant  year  month  day  hour
# 0                              11        True  2020      3   13    21
# 1                              11        True  2021      8    6    21
# ...

# %%
checkin_num = restaurant_checkin_df_clean[['business_id', 'total_number_of_checkin']]
checkin_num.describe()
# Out:
#        total_number_of_checkin
# count                8513259.0
# mean               1480.384854
# std                3754.449822
# min                        1.0
# 25%                      216.0
# 50%                      559.0
# 75%                     1347.0
# max                    40109.0

# %%
checkin_num.duplicated().sum()
# Out:
# 8461941

# %%
checkin_num_clean = checkin_num.drop_duplicates()
checkin_num_clean
# Out:
#                      business_id  total_number_of_checkin
# 0         ---kPU91CF4Lq2-WlRu9Lw                       11
# 22        --0iUa4sNDFiZFrAdIWhZQ                       10
# 42        --7PUidqRWpRSpXebiyxTg                       10
# 62        --8IbOsAAxjKRoYsBFL-PA                       32
# 126       --ZVrH2X2QXBFdCilbirsw                       67
# ...                          ...                      ...
# 17030926  zzjFdJwXuxBOGe9JeY_EMw                       27
# 17030980  zznJox6-nmXlGYNWgTDwQQ                       67
# 17031114  zznZqH9CiAznbkV6fXyHWA                        1
# 17031116  zzu6_r3DxBJuXcjnOYVdTw                       23
# 17031162  zzyx5x0Z7xXWWvWnZFuxlQ                        1
#
# [51318 rows x 2 columns]

# %%
import pandas as pd

merged_attributes = pd.merge(attributes, checkin_num_clean, on='business_id', how='inner')
merged_attributes
# Out:
#                   business_id  stars  review_count  is_open  \
# 0      ---kPU91CF4Lq2-WlRu9Lw    4.5            24        1
# 1      --0iUa4sNDFiZFrAdIWhZQ    3.0            14        1
# 2      --7PUidqRWpRSpXebiyxTg    2.0            12        0
# 3      --8IbOsAAxjKRoYsBFL-PA    3.0            27        0
# 4      --ZVrH2X2QXBFdCilbirsw    4.5            32        0
# ...                       ...    ...           ...      ...
# 51313  zzjFdJwXuxBOGe9JeY_EMw    4.0            47        1
# 51314  zznJox6-nmXlGYNWgTDwQQ    1.5            30        1
# 51315  zznZqH9CiAznbkV6fXyHWA    5.0            12        1
# 51316  zzu6_r3DxBJuXcjnOYVdTw    3.5             8        0
# 51317  zzyx5x0Z7xXWWvWnZFuxlQ    2.5             6        0
#
#        RestaurantsDelivery  OutdoorSeating  BusinessAcceptsCreditCards  \
# 0                        0               1                           1
# 1                        0               0                           0
# ...

# %%
merged_attributes.isnull().sum()
# Out:
# business_id                   0
# stars                         0
# review_count                  0
# is_open                       0
# RestaurantsDelivery           0
# OutdoorSeating                0
# BusinessAcceptsCreditCards    0
# BikeParking                   0
# RestaurantsPriceRange2        0
# RestaurantsTakeOut            0
# WiFi                          0
# Alcohol                       0
# Caters                        0
# RestaurantsAttire             0
# RestaurantsReservations       0
# GoodForKids                   0
# RestaurantsGoodForGroups      0
# HasTV                         0
# NoiseLevel                    0
# Parking                       0
# total_number_of_checkin       0
# dtype: int64

# %%
merged_attributes.to_csv('merged_restaurants_attributes.csv', index=False)

# %%
restaurant_category = restaurant_data_df_clean.iloc[:, :14]
restaurant_category = restaurant_category.drop(['attributes'], axis =1)
restaurant_category.isnull().sum()
# Out:
# business_id        0
# name               0
# address          443
# city               0
# state              0
# postal_code       21
# latitude           0
# longitude          0
# stars              0
# review_count       0
# is_open            0
# categories         0
# hours           7279
# dtype: int64

# %%
restaurant_category.dtypes
# Out:
# business_id      object
# name             object
# address          object
# city             object
# state            object
# postal_code      object
# latitude        float64
# longitude       float64
# stars           float64
# review_count      Int64
# is_open           Int64
# categories       object
# hours            object
# dtype: object

# %%
import pandas as pd

merged_categories = pd.merge(restaurant_category, checkin_num_clean, on='business_id', how='outer')
merged_categories
# Out:
#                   business_id                          name  \
# 0      ---kPU91CF4Lq2-WlRu9Lw             Frankie's Raw Bar
# 1      --0iUa4sNDFiZFrAdIWhZQ  Pupuseria Y Restaurant Melba
# 2      --7PUidqRWpRSpXebiyxTg    Humpty's Family Restaurant
# 3      --8IbOsAAxjKRoYsBFL-PA      The Original Italian Pie
# 4      --ZVrH2X2QXBFdCilbirsw         Chris's Sandwich Shop
# ...                       ...                           ...
# 52281  zzjFdJwXuxBOGe9JeY_EMw          Taste of the Islands
# 52282  zznJox6-nmXlGYNWgTDwQQ                       Dunkin'
# 52283  zznZqH9CiAznbkV6fXyHWA                Que Pasta Nola
# 52284  zzu6_r3DxBJuXcjnOYVdTw                  Cafe Diblasi
# 52285  zzyx5x0Z7xXWWvWnZFuxlQ           Walnut Street Pizza
#
#                        address             city state postal_code   latitude  \
# 0             4903 State Rd 54  New Port Richey    FL       34652  28.217288
# 1         6 S White Horse Pike        Clementon    NJ       08021  39.817850
# ...

# %%
merged_categories.to_csv('merged_categories.csv', index=False)

# %%
restaurant_keywords = {
    "new american", "italian", "french", "restaurants", "american", "steakhouses",
    "modern european", "seafood", "gastropubs", "diners", "basque", "bars", "southern",
    "argentine", "wine bars", "mediterranean", "cocktail bars", "spanish", "burmese",
    "nightlife", "moroccan", "comfort food", "tapas/small plates", "german",
    "persian/iranian", "caribbean", "mexican", "russian", "portuguese", "burgers",
    "breakfast & brunch", "soul food", "lounges", "pizza", "peruvian", "beer bar",
    "greek", "colombian", "polish", "tapas bars", "food court", "cuban", "pubs",
    "latin american", "new mexican cuisine", "thai", "sports bars", "hawaiian", "african",
    "irish pub", "asian fusion", "indonesian", "pasta shops", "whiskey bars", "ethiopian",
    "pop-up restaurants", "turkish", "cajun/creole", "lebanese", "speakeasies",
    "venues & event spaces", "armenian", "salad", "georgian", "barbeque", "tacos",
    "puerto rican", "indian", "chinese", "filipino", "live/raw food", "brazilian",
    "fish & chips", "dinner theater", "british", "breweries", "beer gardens", "szechuan",
    "korean", "vegetarian", "middle eastern", "tex-mex", "venezuelan", "irish", "buffets",
    "vegan", "ukrainian", "music venues", "pan asian", "gluten-free", "event planning & services",
    "arabic", "cafes", "nicaraguan", "cafeteria", "hotels", "seafood markets", "piano bars",
    "afghan", "dim sum", "sandwiches", "piadina", "hookah bars", "teppanyaki", "halal",
    "vietnamese", "uzbek", "salvadoran", "wraps", "caterers", "jazz & blues", "cantonese",
    "malaysian", "himalayan/nepalese", "ramen", "soup", "specialty food", "egyptian",
    "kebab", "butcher", "dive bars", "desserts", "sushi bars", "pakistani", "honduran",
    "singaporean", "themed cafes", "chicken wings", "japanese", "hot dogs", "empanadas",
    "falafel", "hotels & travel", "food stands", "shanghainese", "champagne bars",
    "food delivery services", "izakaya", "creperies", "do-it-yourself food", "delis",
    "laotian", "pancakes", "imported food", "karaoke", "waffles", "food", "chicken shop",
    "polynesian", "poke", "japanese curry", "cheese shops", "guamanian", "street vendors",
    "personal chefs", "hong kong style cafe", "taiwanese", "hot pot", "mongolian",
    "noodles", "fast food", "food trucks", "bulgarian", "beer, wine & spirits", "wineries",
    "wine tasting room", "meat shops"
}

# Function: pick tags from `category` that are relevant to the catering category
def filter_restaurant_tags(categories):
    tags = [tag.strip().lower() for tag in categories.split(', ')]
    filtered_tags = [tag for tag in tags if any(keyword in tag for keyword in restaurant_keywords)]
    return ', '.join(filtered_tags)

# Apply a filter function to extract labels related to catering
merged_categories['filtered_category'] = merged_categories['categories'].apply(filter_restaurant_tags)

# Delete empty `filtered_category` columns
restaurant_category_clean = merged_categories[merged_categories['filtered_category'] != '']

restaurant_category_clean
# Out:
#                   business_id                          name  \
# 0      ---kPU91CF4Lq2-WlRu9Lw             Frankie's Raw Bar
# 1      --0iUa4sNDFiZFrAdIWhZQ  Pupuseria Y Restaurant Melba
# 2      --7PUidqRWpRSpXebiyxTg    Humpty's Family Restaurant
# 3      --8IbOsAAxjKRoYsBFL-PA      The Original Italian Pie
# 4      --ZVrH2X2QXBFdCilbirsw         Chris's Sandwich Shop
# ...                       ...                           ...
# 52281  zzjFdJwXuxBOGe9JeY_EMw          Taste of the Islands
# 52282  zznJox6-nmXlGYNWgTDwQQ                       Dunkin'
# 52283  zznZqH9CiAznbkV6fXyHWA                Que Pasta Nola
# 52284  zzu6_r3DxBJuXcjnOYVdTw                  Cafe Diblasi
# 52285  zzyx5x0Z7xXWWvWnZFuxlQ           Walnut Street Pizza
#
#                        address             city state postal_code   latitude  \
# 0             4903 State Rd 54  New Port Richey    FL       34652  28.217288
# 1         6 S White Horse Pike        Clementon    NJ       08021  39.817850
# ...

# %%
restaurant_category_clean['categories_split'] = restaurant_category_clean['filtered_category'].str.split(', ')

df_exploded = restaurant_category_clean.explode('categories_split')
df_exploded = df_exploded.rename(columns={'categories_split': 'category'})
df_exploded = df_exploded.drop(['categories', 'filtered_category'], axis =1)
df_exploded
# Out:
# <ipython-input-48-5bb46867846c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   restaurant_category_clean['categories_split'] = restaurant_category_clean['filtered_category'].str.split(', ')
#                   business_id                 name           address  \
# 0      ---kPU91CF4Lq2-WlRu9Lw    Frankie's Raw Bar  4903 State Rd 54
# 0      ---kPU91CF4Lq2-WlRu9Lw    Frankie's Raw Bar  4903 State Rd 54
# 0      ---kPU91CF4Lq2-WlRu9Lw    Frankie's Raw Bar  4903 State Rd 54
# 0      ---kPU91CF4Lq2-WlRu9Lw    Frankie's Raw Bar  4903 State Rd 54
# 0      ---kPU91CF4Lq2-WlRu9Lw    Frankie's Raw Bar  4903 State Rd 54
# ...                       ...                  ...               ...
# ...

# %%
df_exploded.to_csv('category.csv', index=False)

# %% [markdown]
# ### 上面是筠姜的
